# %%
import sys, os
from cProfile import label

import numpy as np
import matplotlib.pyplot as plt
import warnings
from scipy.constants import c

# %%
sys.path.append('C:\\Program Files\\Lumerical\\v221\\api\\python')
sys.path.append('C:\\Program Files\\Lumerical\\v221\\api\\python\\lumapi.py')

# %%
warnings.filterwarnings("ignore", category=SyntaxWarning)
import lumapi

# %%
nm = 1e-9
um = 1e-6

# %%
icApi = lumapi.INTERCONNECT()

# %%
icApi.switchtolayout()
icApi.deleteall()

# %%
#ONA
#todo: change the way i'm doing this, I have to use directional couplers
icApi.addelement('Optical Network Analyzer')
icApi.set('name', 'ona1')
icApi.set('number of input ports', 2)
icApi.set('input parameter', 2)
icApi.set('start frequency', (c/(1500*nm)))
icApi.set('stop frequency', (c/(1600*nm)))

# %% [markdown]
# <h1>Ideal case</h1>

# %%
#directional couplers
icApi.addelement('Waveguide Coupler')
icApi.set('name', 'dc1')
icApi.addelement('Waveguide Coupler')
icApi.set('name', 'dc2')
#straight waveguides
icApi.addelement('Straight Waveguide')
icApi.set('name', 'wg1')
icApi.addelement('Straight Waveguide')
icApi.set('name', 'wg2')

# %%
#positions
#dcs
icApi.setposition('ona1',0,0)
icApi.setposition('dc1',25,500)
icApi.setposition('dc2',25,250)
#waveguides
icApi.setposition('wg1',-200,350)
icApi.rotateelement('wg1')
icApi.setposition('wg2',200,350)
icApi.rotateelement('wg2')

# %%
#conections
#creating the ring resonator
icApi.connect('dc1','port 1','wg1','port 2')
icApi.connect('dc1','port 2','wg2','port 2')
#connecting the ring resonator to the ona
# Out:
# ---------------------------------------------------------------------------
# LumApiError                               Traceback (most recent call last)
# Cell In[501], line 2
#       1 #conections
# ----> 2 icApi.connect('ona1','input 1','ring1','port 1')
#       3 icApi.connect('ona1','output','ring1','port 2')
#       4 #creating the ring resonator
#
# File C:\Program Files\Lumerical\v221\api\python\lumapi.py:1153, in Lumerical.__init__.<locals>.<lambda>(self, *args)
#    1150     method = (lambda x: lambda self, *args, **kwargs:
#    1151     appCallWithConstructor(self, x, args, **kwargs))(name)
#    1152 else:
# -> 1153     method = (lambda x: lambda self, *args: appCall(self, x, args))(name)
#    1154 method.__name__ = str(name)
#    1155 try:
#
# File C:\Program Files\Lumerical\v221\api\python\lumapi.py:800, in appCall(self, name, *args)
#     798         argLumTypes = lumTypes(list(args[0]))
# ...

# %% [markdown]
# <h2>FSR for the ideal case</h2>
#
# the values for ng and neff used here were determined by previous simulations (check mzi repository)

# %%
ng = 4.355
neff = 2.355
lambda0 = 1550*nm
FSR_values = [1,10,20]
Lr = []
for FSR in FSR_values:
    Lr.append((lambda0**2)/(ng*FSR*nm))

# %%
#ring simulated parameters
icApi.set('effective index 1', neff)
icApi.set('effective index 2', neff)
icApi.set('group index 1', ng)
icApi.set('group index 2', ng)

# %%
print((Lr[0]/2)/um)
# Out:
# 275.83237657864527

# %% [markdown]
# <h2>1nm simulation</h2>

# %%
icApi.switchtolayout()
icApi.select('ring1')
icApi.set('frequency', (c/(1550*nm)))
icApi.set('coupling coefficient 1 1', 0.3)
icApi.set('coupling coefficient 1 2', 0.3)
icApi.set('length', Lr[0])

# %%
icApi.save('IdealRingResonator_1nm')
icApi.run()

# %%
#coupling values -> 0.4
data = icApi.getresult('ONA_1', 'input 1/mode 1/gain')
data2 = icApi.getresult('ONA_1', 'input 2/mode 1/gain')
plt.plot(data['wavelength']/nm, data['TE gain (dB)'],color='black')
plt.plot(data2['wavelength']/nm, data2['TE gain (dB)'],color='red')
plt.xlim(1500, 1600)
plt.ylim(-40, 1)
plt.xlabel('Wavelength [nm]')
plt.ylabel('Transmission [dB]')
plt.grid()
plt.title('Simulation using ideal devices FSR = 1nm')
#zooming to see the FSR on the transmission graph
zoom = plt.axes([0.5,0.19,0.3,0.3])
zoom.set_xlim(1551, 1554)
zoom.set_ylim(-15,0.5)
zoom.hlines(-10,xmin=1552.3,xmax=1553.3, color='blue',linestyles='dashed')
zoom.plot(data['wavelength']/nm, data['TE gain (dB)'],color='black')
zoom.plot(data2['wavelength']/nm, data2['TE gain (dB)'],color='red')
plt.savefig('Simulation using ideal devices FSR = 1nm.png')

# %% [markdown]
# <h1>Obtaining $FRS_2$ by a given FSR variating $FSR_1$</h1>
# <h2>e.g.: $FSR_2$(FSR, FSR_1), FSR = k<h2>
# $FSR_2 = \frac{FSR}{|1-\frac{FSR}{FSR_1}|}$

# %%
FSR1 = np.linspace(0.1*nm,15*nm, 100)
FSR = 20*nm
FSR2 = FSR/(np.abs(1-(FSR/FSR1)))
plt.plot(FSR1/nm,FSR2/nm)
#plt.hlines(13,xmin=0,xmax=8, color='r',linestyles='dashed')
plt.vlines(8,ymin=0,ymax=13, color='r',linestyles='dashed')
plt.ylim(min(FSR1/nm), max(FSR2/nm))
plt.xlim(min(FSR1/nm), max(FSR1/nm))
plt.xlabel('FSR1 [nm]')
plt.ylabel('FSR2 [nm]')
plt.title(rf'$FSR_2$($FSR_1$, {FSR/nm})')
plt.grid()

# %%
print(max(FSR2))
# Out:
# 6.000000000000002e-08

# %% [markdown]
# <h2>10nm simulation</h2>

# %%
20*1e-16
# Out:
# 2e-15

# %%
icApi.switchtolayout()
icApi.select('ring1')
icApi.set('frequency', (c/(1550*nm)))
icApi.set('length', Lr[1])

# %%
icApi.select('ring1')
icApi.set('frequency', (c/(1550*nm)))
icApi.set('length', Lr[1])

# %%
icApi.save('IdealRingResonator_10nm')
icApi.run()

# %%
data = icApi.getresult('ona1', 'input 1/mode 1/gain')
data2 = icApi.getresult('ona1', 'input 2/mode 1/gain')
plt.plot(data['wavelength']/nm, data['TE gain (dB)'],color='black')
plt.plot(data2['wavelength']/nm, data2['TE gain (dB)'],color='red')
fsrh=1538
plt.hlines(-23,xmin=fsrh,xmax=fsrh+10, color='r',linestyles='dashed')
plt.xlim(1500, 1600)
plt.ylim(-40, 1)
plt.xlabel('Wavelength [nm]')
plt.ylabel('Transmission [dB]')
plt.grid()
plt.title('Simulation using ideal devices FSR = 10nm')
plt.savefig('Simulation using ideal devices FSR = 10nm.png')

# %% [markdown]
# <h2>20nm simulation</h2>

# %%
icApi.switchtolayout()
icApi.select('ring1')
icApi.set('frequency', (c/(1550*nm)))
icApi.set('length', Lr[2])

# %%
icApi.select('ring1')
icApi.set('frequency', (c/(1550*nm)))
icApi.set('length', Lr[2])

# %%
icApi.save('IdealRingResonator_20nm')
icApi.run()

# %%
data = icApi.getresult('ona1', 'input 1/mode 1/gain')
data2 = icApi.getresult('ona1', 'input 2/mode 1/gain')
plt.plot(data['wavelength']/nm, data['TE gain (dB)'],color='black')
plt.plot(data2['wavelength']/nm, data2['TE gain (dB)'],color='red')
fsrh_20 = 1548
plt.hlines(-23,xmin=fsrh_20,xmax=fsrh_20+20, color='r',linestyles='dashed')
plt.xlim(1500, 1600)
plt.ylim(-40, 1)
plt.xlabel('Wavelength [nm]')
plt.ylabel('Transmission [dB]')
plt.grid()
plt.title('Simulation using ideal devices FSR = 20nm')
plt.savefig('Simulation using ideal devices FSR = 20nm.png')

# %% [markdown]
# <h1>SiEPIC PDK devices</h1>

# %%
icApi.switchtolayout()
icApi.select('ring1')
icApi.delete()

# %%
icApi.addelement('ebeam_dc_halfring_straight')
icApi.set('name', 'dc1')
icApi.addelement('ebeam_dc_halfring_straight')
icApi.set('name', 'dc2')
icApi.rotateelement('dc2')
icApi.rotateelement('dc2')

# %%
#positions and conexions
icApi.setposition('dc1',200,400)
icApi.setposition('dc2',200,200)

# %%
icApi.connect('ona1','output','dc1','port 1')
icApi.connect('dc1','port 2','dc2','port 4')
icApi.connect('dc2','port 2','dc1','port 4')
icApi.connect('dc2', 'port 3', 'ona1', 'input 2')
icApi.connect('dc1', 'port 3', 'ona1', 'input 1')
# Out:
# 1.0

# %% [markdown]
# <h2>1nm simulation</h2>

# %%
Lc = 1*um
icApi.switchtolayout()
icApi.select('dc1')
icApi.set('Lc', Lc)
icApi.set('radius',(Lr[0]-Lc)/(2*np.pi))
icApi.select('dc2')
icApi.set('Lc', Lc)
icApi.set('radius',(Lr[0]-Lc)/(2*np.pi))

# %%
icApi.save('PDKRingResonator_1nm')
icApi.run()

# %%
data = icApi.getresult('ona1', 'input 1/mode 1/gain')
data2 = icApi.getresult('ona1', 'input 2/mode 1/gain')
plt.plot(data['wavelength']/nm, data['TE gain (dB)'],color='black')
plt.plot(data2['wavelength']/nm, data2['TE gain (dB)'],color='red')
plt.hlines(-3,xmin=1544,xmax=1564, color='black',linestyles='dashed')
plt.xlim(1500, 1600)
plt.ylim(-40, 1)
plt.xlabel('Wavelength [nm]')
plt.ylabel('Transmission [dB]')
plt.grid()
plt.title('Simulation using pdk devices FSR = 1nm')
plt.savefig('Simulation using pdk devices FSR = 1nm.png')

# %% [markdown]
# <h2>10nm simulation</h2>

# %%
icApi.switchtolayout()
icApi.select('dc1')
icApi.set('radius',(Lr[1]-Lc)/(2*np.pi))
icApi.select('dc2')
icApi.set('radius',(Lr[1]-Lc)/(2*np.pi))

# %%
icApi.save('PDKRingResonator_10nm')
icApi.run()

# %%
data = icApi.getresult('ona1', 'input 1/mode 1/gain')
data2 = icApi.getresult('ona1', 'input 2/mode 1/gain')
plt.plot(data['wavelength']/nm, data['TE gain (dB)'],color='black')
plt.plot(data2['wavelength']/nm, data2['TE gain (dB)'],color='red')
fsrh_10 = 1545
plt.hlines(-5,xmin=fsrh_10,xmax=fsrh_10+10, color='r',linestyles='dashed')
plt.xlim(1500, 1600)
plt.ylim(-40, 1)
plt.xlabel('Wavelength [nm]')
plt.ylabel('Transmission [dB]')
plt.grid()
plt.title('Simulation using pdk devices FSR = 10nm')
plt.savefig('Simulation using pdk devices FSR = 10nm.png')

# %% [markdown]
# <h2>20nm simulation</h2>

# %%
icApi.switchtolayout()
icApi.select('dc1')
icApi.set('radius',(Lr[2]-Lc)/(2*np.pi))
icApi.select('dc2')
icApi.set('radius',(Lr[2]-Lc)/(2*np.pi))

# %%
icApi.save('PDKRingResonator_20nm')
icApi.run()

# %%
data = icApi.getresult('ona1', 'input 1/mode 1/gain')
data2 = icApi.getresult('ona1', 'input 2/mode 1/gain')
plt.plot(data['wavelength']/nm, data['TE gain (dB)'],color='black')
plt.plot(data2['wavelength']/nm, data2['TE gain (dB)'],color='red')
fsrh_10 = 1544
plt.hlines(-5,xmin=fsrh_10,xmax=fsrh_10+20, color='r',linestyles='dashed')
plt.xlim(1500, 1600)
plt.ylim(-40, 1)
plt.xlabel('Wavelength [nm]')
plt.ylabel('Transmission [dB]')
plt.grid()
plt.title('Simulation using pdk devices FSR = 20nm')
plt.savefig('Simulation using pdk devices FSR = 20nm.png')
